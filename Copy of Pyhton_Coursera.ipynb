# %% [markdown]
# Python for finance COURSERA

# %%
import pandas as pd

# %%
# !git clone https://github.com/ignaciocuadrado01/FiProjects.git
# Out:
# fatal: destination path 'FiProjects' already exists and is not an empty directory.

# %%
# !ls FiProjects/
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp FiProjects/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d stefanoleone992/mutual-funds-and-etfs
# Out:
# Dataset URL: https://www.kaggle.com/datasets/stefanoleone992/mutual-funds-and-etfs
# License(s): CC0-1.0
# ...
#  87% 309M/353M [00:00<00:00, 608MB/s]
# 100% 353M/353M [00:00<00:00, 652MB/s]

# %%
# !unzip mutual-funds-and-etfs.zip -d mutual_funds_data
# Out:
# Archive:  mutual-funds-and-etfs.zip
#   inflating: mutual_funds_data/ETF prices.csv
#   inflating: mutual_funds_data/ETFs.csv
#   inflating: mutual_funds_data/MutualFund prices - A-E.csv
#   inflating: mutual_funds_data/MutualFund prices - F-K.csv
#   inflating: mutual_funds_data/MutualFund prices - L-P.csv
#   inflating: mutual_funds_data/MutualFund prices - Q-Z.csv
#   inflating: mutual_funds_data/MutualFunds.csv

# %%
df = pd.read_csv('mutual_funds_data/ETF prices.csv')
df.head()
# Out:
#   fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0         AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1         AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2         AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3         AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4         AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100

# %%
# !ls /content/
# Out:
# FiProjects  mutual-funds-and-etfs.zip  mutual_funds_data  sample_data

# %%
# !git config --global user.email "ignaciocuadrado01@gmail.com"
# !git config --global user.name "ignaciocuadrado01"

# !git clone https://github.com/ignaciocuadrado01/FiProjects.git
# %cd FiProjects/
# Out:
# Cloning into 'FiProjects'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/FiProjects/FiProjects

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
# 'Copy of Pyhton_Coursera.ipynb'
